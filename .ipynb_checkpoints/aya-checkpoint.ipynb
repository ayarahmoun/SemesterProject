# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Classification twitter

# %%
df_tweets = pd.read_csv('/Users/mac/Desktop/01_09_21TO11_09.csv')
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,1,2,3,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_tweets
# Out:
#        Unnamed: 0            author_id        username author_followers  \
# 0               0             75639172  CoachGetwright            207.0
# 1               1  1112964869148467200     TR380009080             75.0
# 2               2  1189821029826416640   mercybhells09             68.0
# 3               3            164498924    loggertrades            642.0
# 4               4            443073989      TechDev_52         401184.0
# ...           ...                  ...             ...              ...
# 591554      39060  1107640745761091586    Cryptonomia1             1780
# 591555      39061            597196999         cRe5520              260
# 591556      39062  1413298648939700234   CryptoNerdApp               78
# 591557      39063  1362590381267947520   valueofcrypto              462
# 591558      39064  1353870176031133696   welcomecatena             1818
#
#         author_tweets                                 author_description  \
# ...

# %%
#x contained NaN
#df_tweets = df_tweets[~df_tweets['author_followers'].isnull()]

# %%
df_tweets['author_followers'] = pd.to_numeric(df_tweets['author_followers'], errors='coerce')
# Out:
# /var/folders/9h/13pr4vr90tq8fry9k7v3mmxh0000gn/T/ipykernel_1033/518817201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweets['author_followers'] = pd.to_numeric(df_tweets['author_followers'], errors='coerce')

# %%
df_sorted_by_author = df_tweets.sort_values(by= 'author_followers', ascending=False)

# %%
df_sorted_by_author.head()
# Out:
#        Unnamed: 0           author_id username  author_followers  \
# 354981      17932  877807935493033984  binance         9935351.0
# 217039      31632  877807935493033984  binance         9935206.0
# 17153       17149  877807935493033984  binance         9935079.0
# 574042      21548  877807935493033984  binance         9935062.0
# 563033      10547  877807935493033984  binance         9935051.0
#
#         author_tweets                                 author_description  \
# 354981        23271.0  The world’s leading blockchain ecosystem and d...
# 217039        23271.0  The world’s leading blockchain ecosystem and d...
# 17153         23271.0  The world’s leading blockchain ecosystem and d...
# 574042        23272.0  The world’s leading blockchain ecosystem and d...
# 563033        23272.0  The world’s leading blockchain ecosystem and d...
#
#        author_location                                               text  \
# ...

# %%
df_tweets = df_tweets.drop(thresh = 6)

# %%
df_tweets['news_category'] = ''
# Out:
# /var/folders/9h/13pr4vr90tq8fry9k7v3mmxh0000gn/T/ipykernel_1033/1584053837.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweets['news_category'] = ''

# %%
df_tweets.loc[df_tweets['author_followers'] <= 1000, 'news_category'] = 'Less Credible' 
df_tweets.loc[df_tweets['author_followers'] > 1000, 'news_category'] = 'Credible'
# Out:
# /Users/mac/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_tweets.news_category.unique()
# Out:
# array(['Less Credible', 'Credible', ''], dtype=object)

# %%
df_tweets
# Out:
#        Unnamed: 0            author_id        username  author_followers  \
# 0               0             75639172  CoachGetwright             207.0
# 1               1  1112964869148467200     TR380009080              75.0
# 2               2  1189821029826416640   mercybhells09              68.0
# 3               3            164498924    loggertrades             642.0
# 4               4            443073989      TechDev_52          401184.0
# ...           ...                  ...             ...               ...
# 591554      39060  1107640745761091586    Cryptonomia1            1780.0
# 591555      39061            597196999         cRe5520             260.0
# 591556      39062  1413298648939700234   CryptoNerdApp              78.0
# 591557      39063  1362590381267947520   valueofcrypto             462.0
# 591558      39064  1353870176031133696   welcomecatena            1818.0
#
#         author_tweets                                 author_description  \
# ...

# %%
df_tweets['news_category'] = ['less credible' if df_tweets['author_followers'] < 1000.0 ]
# Out:
#   File "/var/folders/9h/13pr4vr90tq8fry9k7v3mmxh0000gn/T/ipykernel_1033/2798698381.py", line 1
#     df_tweets['news_category'] = ['less credible' if df_tweets['author_followers'] < 1000.0 ]
#                                                                                             ^
# SyntaxError: invalid syntax

# %%
def nb_followers(df): 
    if df['author_followers'] < 1000:
        df_tweets['news_category'] = 'less credible'
    if df['author_followers'] > 10000 :
        df_tweets['news_category'] = 'credible'

# %%
nb_followers(df_tweets)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9h/13pr4vr90tq8fry9k7v3mmxh0000gn/T/ipykernel_1033/294150827.py in <module>
# ----> 1 nb_followers(df_tweets)
#
# /var/folders/9h/13pr4vr90tq8fry9k7v3mmxh0000gn/T/ipykernel_1033/409436110.py in nb_followers(df)
#       1 def nb_followers(df):
# ----> 2     if df['author_followers'] < 1000:
#       3         df_tweets['news_category'] = 'less credible'
#       4     if df['author_followers'] > 10000 :
#       5         df_tweets['news_category'] = 'credible'
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ...

# %%
def retweet(retweets):
    if retweet  200:
        retweets = reliable

# %%
if first tweet : 
    author_tweets < 5 ?

# %%
Classification news
# Out:
#   File "/var/folders/9h/13pr4vr90tq8fry9k7v3mmxh0000gn/T/ipykernel_1033/3938796325.py", line 1
#     Classification news
#                    ^
# SyntaxError: invalid syntax

# %%
if source = new
gdelt = maybe des dupplica -> supprimer

# %%
df['news_category'] = 'low-quality'
df['news_category'] = 'less known'
df['news_category'] = 'less credible'
df['news_category'] = 'credible/mainstream'
